# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv('Data/finalTrain.csv')
data.head(3)
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2  \
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude
# 0            30.327968             78.046106                   30.397968  \
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked
# 0                    78.116106  12-02-2022       21:55             22:10  \
# 1                    76.347589  13-02-2022       14:55             15:05
# 2                    74.006619  04-03-2022       17:30             17:40
#
#   Weather_conditions Road_traffic_density  Vehicle_condition Type_of_order
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45584 entries, 0 to 45583
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           45584 non-null  object
#  1   Delivery_person_ID           45584 non-null  object
#  2   Delivery_person_Age          43730 non-null  float64
#  3   Delivery_person_Ratings      43676 non-null  float64
#  4   Restaurant_latitude          45584 non-null  float64
#  5   Restaurant_longitude         45584 non-null  float64
#  6   Delivery_location_latitude   45584 non-null  float64
#  7   Delivery_location_longitude  45584 non-null  float64
#  8   Order_Date                   45584 non-null  object
#  9   Time_Orderd                  43853 non-null  object
#  10  Time_Order_picked            45584 non-null  object
#  11  Weather_conditions           44968 non-null  object
# ...

# %%
data.describe().T
# Out:
#                                count       mean        std        min
# Delivery_person_Age          43730.0  29.566911   5.815064  15.000000  \
# Delivery_person_Ratings      43676.0   4.633774   0.334744   1.000000
# Restaurant_latitude          45584.0  17.017948   8.185674 -30.905562
# Restaurant_longitude         45584.0  70.229684  22.885575 -88.366217
# Delivery_location_latitude   45584.0  17.465480   7.335562   0.010000
# Delivery_location_longitude  45584.0  70.844161  21.120578   0.010000
# Vehicle_condition            45584.0   1.023385   0.839055   0.000000
# multiple_deliveries          44591.0   0.744635   0.572510   0.000000
# Time_taken (min)             45584.0  26.293963   9.384298  10.000000
#
#                                    25%        50%        75%        max
# Delivery_person_Age          25.000000  30.000000  35.000000  50.000000
# Delivery_person_Ratings       4.500000   4.700000   4.900000   6.000000
# ...

# %%
sns.distplot(data['Delivery_person_Ratings'],hist=False)
# Out:
# C:\Users\Suyash\AppData\Local\Temp\ipykernel_16908\2536837946.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Delivery_person_Ratings'],hist=False)
# <Axes: xlabel='Delivery_person_Ratings', ylabel='Density'>

# %%
sns.distplot(data['Delivery_person_Age'],hist=False)
# Out:
# C:\Users\Suyash\AppData\Local\Temp\ipykernel_16908\2702145456.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Delivery_person_Age'],hist=False)
# <Axes: xlabel='Delivery_person_Age', ylabel='Density'>

# %%
data.isnull().sum()
# Out:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age            1854
# Delivery_person_Ratings        1908
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1731
# Time_Order_picked                 0
# Weather_conditions              616
# Road_traffic_density            601
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             993
# Festival                        228
# City                           1200
# Time_taken (min)                  0
# dtype: int64

# %%
data['Road_traffic_density'].value_counts()
# Out:
# Low       15476
# Jam       14139
# Medium    10945
# High       4423
# Name: Road_traffic_density, dtype: int64

# %%
data['City'].value_counts()
# Out:
# Metropolitian    34087
# Urban            10133
# Semi-Urban         164
# Name: City, dtype: int64

# %%
data['multiple_deliveries'].value_counts()
# Out:
# 1.0    28151
# 0.0    14094
# 2.0     1985
# 3.0      361
# Name: multiple_deliveries, dtype: int64

# %%
R = 6371
def deg_to_rad(degrees):
    return degrees * (np.pi/180)

# Function to calculate the distance between two points using the haversine formula
def distcalculate(lat1, lon1, lat2, lon2):
    d_lat = deg_to_rad(lat2-lat1)
    d_lon = deg_to_rad(lon2-lon1)
    a = np.sin(d_lat/2)**2 + np.cos(deg_to_rad(lat1)) * np.cos(deg_to_rad(lat2)) * np.sin(d_lon/2)**2
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1-a))
    return R * c
  
# Calculate the distance between each pair of points
data['distance'] = np.nan

for i in range(len(data)):
    data.loc[i, 'distance'] = distcalculate(data.loc[i, 'Restaurant_latitude'], 
                                        data.loc[i, 'Restaurant_longitude'], 
                                        data.loc[i, 'Delivery_location_latitude'], 
                                        data.loc[i, 'Delivery_location_longitude'])

# %%
data.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2  \
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude
# 0            30.327968             78.046106                   30.397968  \
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd  ...
# ...

# %%
indextodrop=data[data['distance']>25].index
data=data.drop(indextodrop)

# %%
sns.boxplot(x='Festival',
            y='Time_taken (min)',
            data=data,
            )
# Out:
# <Axes: xlabel='Festival', ylabel='Time_taken (min)'>

# %%
sns.boxplot(x='City',
            y='Time_taken (min)',
            data=data,
            )
# Out:
# <Axes: xlabel='City', ylabel='Time_taken (min)'>

# %%
sns.regplot(x='multiple_deliveries',y='Time_taken (min)',data=data)
# Out:
# <Axes: xlabel='multiple_deliveries', ylabel='Time_taken (min)'>

# %%
sns.boxplot(x='Road_traffic_density',
            y='Time_taken (min)',
            data=data,
            )
# Out:
# <Axes: xlabel='Road_traffic_density', ylabel='Time_taken (min)'>

# %%
sns.boxplot(x='Weather_conditions',
            y='Time_taken (min)',
            data=data,
            )
# Out:
# <Axes: xlabel='Weather_conditions', ylabel='Time_taken (min)'>

# %%
sns.boxplot(x='Type_of_vehicle',
            y='Time_taken (min)',
            data=data,
            hue='Type_of_order')
# Out:
# <Axes: xlabel='Type_of_vehicle', ylabel='Time_taken (min)'>

# %%
So there is not much difference between the time taken by delivery partners depending on the vehicle they are
driving and the type of food they are delivering.

# %%
sns.boxplot(x='Type_of_vehicle',
            y='Time_taken (min)',
            data=data,
            hue='Vehicle_condition')
# Out:
# <Axes: xlabel='Type_of_vehicle', ylabel='Time_taken (min)'>

# %%
sns.regplot(x='Delivery_person_Age',y='Time_taken (min)',data=data)
# Out:
# <Axes: xlabel='Delivery_person_Age', ylabel='Time_taken (min)'>

# %%
There is a linear relationship between the time taken to deliver the food and the age of the delivery partner. 
It means young delivery partners take less time to deliver the food compared to the elder partners.

# %%
sns.regplot(x='Delivery_person_Ratings',y='Time_taken (min)',data=data)
# Out:
# <Axes: xlabel='Delivery_person_Ratings', ylabel='Time_taken (min)'>

# %%
There is an inverse linear relationship between the time taken to deliver the food and the ratings of the delivery partner

# %%
data.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            30.327968             78.046106                   30.397968
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd  ...  \
# ...

# %%
df=data.drop(labels=['ID','Delivery_person_ID','Restaurant_latitude','Restaurant_longitude','Delivery_location_latitude','Delivery_location_longitude','Order_Date','Time_Orderd'],axis=1)

# %%
df.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings Time_Order_picked  \
# 0                 36.0                      4.2             22:10
# 1                 21.0                      4.7             15:05
# 2                 23.0                      4.7             17:40
# 3                 34.0                      4.3             09:30
# 4                 24.0                      4.7             20:05
#
#   Weather_conditions Road_traffic_density  Vehicle_condition Type_of_order  \
# 0                Fog                  Jam                  2         Snack
# 1             Stormy                 High                  1          Meal
# 2         Sandstorms               Medium                  1        Drinks
# 3         Sandstorms                  Low                  0        Buffet
# 4                Fog                  Jam                  1         Snack
#
#   Type_of_vehicle  multiple_deliveries Festival           City  \
# ...

# %%
df=df.drop(labels=['Time_Order_picked','Weather_conditions','Type_of_order','City'],axis=1)

# %%
data['City'].value_counts()
# Out:
# Metropolitian    34087
# Urban            10133
# Semi-Urban         164
# Name: City, dtype: int64

# %%
data['Festival'].value_counts()
# Out:
# No     44460
# Yes      896
# Name: Festival, dtype: int64

# %%
df.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings Road_traffic_density  \
# 0                 36.0                      4.2                  Jam
# 1                 21.0                      4.7                 High
# 2                 23.0                      4.7               Medium
# 3                 34.0                      4.3                  Low
# 4                 24.0                      4.7                  Jam
#
#    Vehicle_condition Type_of_vehicle  multiple_deliveries Festival  \
# 0                  2      motorcycle                  3.0       No
# 1                  1      motorcycle                  1.0       No
# 2                  1         scooter                  1.0       No
# 3                  0      motorcycle                  0.0       No
# 4                  1         scooter                  1.0       No
#
#    Time_taken (min)   distance
# 0                46  10.280582
# 1                23   6.242319
# 2                21  13.787860
# ...

# %%
num_cols=['Delivery_person_Age','Delivery_person_Ratings','Vehicle_condition','multiple_deliveries','distance']

# %%
cat_cols=['Road_traffic_density','Type_of_vehicle','Festival','Weather_conditions','City']

# %%
data['Road_traffic_density'].value_counts()
# Out:
# Low       15476
# Jam       14139
# Medium    10945
# High       4423
# Name: Road_traffic_density, dtype: int64

# %%
data['Type_of_vehicle'].value_counts()
# Out:
# motorcycle          26429
# scooter             15273
# electric_scooter     3814
# bicycle                68
# Name: Type_of_vehicle, dtype: int64

# %%
data['Weather_conditions'].value_counts()
# Out:
# Fog           7653
# Stormy        7584
# Cloudy        7533
# Sandstorms    7494
# Windy         7422
# Sunny         7282
# Name: Weather_conditions, dtype: int64

# %%
data['City'].value_counts()
# Out:
# Metropolitian    34087
# Urban            10133
# Semi-Urban         164
# Name: City, dtype: int64

# %%
cat_Traffic_density=['Low','Medium','High','Jam'] # ordinal encoder
cat_type_of_vehical=['motorcycle','scooter','electric_scooter','bicycle'] # onehot encoder
cat_festival=['No','Yes']#onehot
cat_weather=['Fog','Stormy','Cloudy','Sandstorms','Windy','Sunny']#onehot
cat_city=['Metropolitian','Urban','Semi-Urban']#onehot
