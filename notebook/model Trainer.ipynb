# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('Data/finalTrain.csv')
data.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2  \
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude
# 0            30.327968             78.046106                   30.397968  \
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked
# ...

# %%
data['Time_Orderd']=data['Time_Orderd'].replace('0.458333333','0')
data['Time_Orderd']=data['Time_Orderd'].replace('0.958333333','0')
data['Time_Orderd']=data['Time_Orderd'].replace('0.791666667','0')
data['Time_Orderd']=data['Time_Orderd'].replace('0.833333333','0')
data['Time_Orderd']=data['Time_Orderd'].replace('0.666666667','0')
data['Time_Orderd']=data['Time_Orderd'].replace('0.416666667','0')
data['Time_Orderd']=data['Time_Orderd'].replace('0.916666667','0')
data['Time_Orderd']=data['Time_Orderd'].replace('0.708333333','0')
data['Time_Orderd']=data['Time_Orderd'].replace('0.541666667','0')
data['Time_Orderd']=data['Time_Orderd'].replace('0.583333333','0')
data['Time_Orderd']=data['Time_Orderd'].replace('0','00:00')
data['Time_Orderd']=data['Time_Orderd'].replace('0.375','00:00')
data['Time_Orderd']=data['Time_Orderd'].replace('0.875','00:00')
data['Time_Orderd']=data['Time_Orderd'].replace('0.5','00:00')
data['Time_Orderd']=data['Time_Orderd'].replace('0.75','00:00')
data['Time_Orderd']=data['Time_Orderd'].replace('NaT','00:00')

# %%
data['Time_Orderd'].unique()
# Out:
# array(['21:55', '14:55', '17:30', '09:20', '19:50', '20:25', '20:30',
#        '20:40', '21:15', '20:20', '22:30', '08:15', '19:30', '12:25',
#        '18:35', '20:35', '23:20', '21:20', '23:35', '22:35', '23:25',
#        '13:35', '21:35', '18:55', '14:15', '00:00', '09:45', '08:40',
#        '17:25', nan, '19:45', '19:10', '10:55', '21:40', '16:45', '11:30',
#        '15:10', '22:45', '22:10', '20:45', '22:50', '17:55', '09:25',
#        '20:15', '22:25', '22:40', '23:50', '15:25', '10:20', '20:55',
#        '10:40', '15:55', '20:10', '12:10', '15:30', '10:35', '21:10',
#        '20:50', '12:35', '23:40', '18:15', '18:20', '11:45', '12:45',
#        '23:30', '10:50', '21:25', '10:10', '17:50', '22:20', '12:40',
#        '23:55', '10:25', '08:45', '23:45', '19:55', '22:15', '23:10',
#        '09:15', '18:25', '18:45', '16:50', '1', '14:20', '10:15', '08:50',
#        '17:45', '16:35', '08:30', '21:45', '19:40', '14:50', '18:10',
# ...

# %%
data['Time_Orderd']=data['Time_Orderd'].replace('1','00:00')
data['Time_Orderd']=data['Time_Orderd'].replace('0.625','00:00')

# %%
t2=pd.to_datetime(data['Time_Orderd'])
# Out:
# C:\Users\Suyash\AppData\Local\Temp\ipykernel_11388\4027616484.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   t2=pd.to_datetime(data['Time_Orderd'])

# %%
t2.value_counts()
# Out:
# Time_Orderd
# 2023-04-21 00:00:00    4068
# 2023-04-21 21:55:00     461
# 2023-04-21 17:55:00     456
# 2023-04-21 22:20:00     448
# 2023-04-21 21:35:00     446
#                        ...
# 2023-04-21 12:25:00      57
# 2023-04-21 14:30:00      57
# 2023-04-21 14:15:00      56
# 2023-04-21 13:20:00      52
# 2023-04-21 16:30:00      51
# Name: count, Length: 161, dtype: int64

# %%
data['Time_Order_picked']=data['Time_Order_picked'].replace('0.458333333','00:00')
data['Time_Order_picked']=data['Time_Order_picked'].replace('0.541666667','00:00')
data['Time_Order_picked']=data['Time_Order_picked'].replace('0.916666667','00:00')
data['Time_Order_picked']=data['Time_Order_picked'].replace('1','00:00')
data['Time_Order_picked']=data['Time_Order_picked'].replace('0.625','00:00')
data['Time_Order_picked']=data['Time_Order_picked'].replace('0.75','00:00')
data['Time_Order_picked']=data['Time_Order_picked'].replace('0.375','00:00')
data['Time_Order_picked']=data['Time_Order_picked'].replace('0.791666667','00:00')
data['Time_Order_picked']=data['Time_Order_picked'].replace('0.666666667','00:00')
data['Time_Order_picked']=data['Time_Order_picked'].replace('0.958333333','00:00')
data['Time_Order_picked']=data['Time_Order_picked'].replace('0.833333333','00:00')
data['Time_Order_picked']=data['Time_Order_picked'].replace('0.875','00:00')
data['Time_Order_picked']=data['Time_Order_picked'].replace('0.583333333','00:00')
data['Time_Order_picked']=data['Time_Order_picked'].replace('0.416666667','00:00')
data['Time_Order_picked']=data['Time_Order_picked'].replace('0.5','00:00')
data['Time_Order_picked']=data['Time_Order_picked'].replace('24:05','00:00')
data['Time_Order_picked']=data['Time_Order_picked'].replace('24:15','00:00')

# %%
data['Time_Order_picked'].unique()
# Out:
# array(['22:10', '15:05', '17:40', '09:30', '20:05', '20:35', '15:10',
#        '20:40', '20:50', '21:30', '20:25', '22:45', '08:30', '19:45',
#        '12:30', '18:50', '23:30', '21:35', '23:45', '22:50', '22:40',
#        '23:35', '13:40', '21:45', '19:10', '14:25', '11:10', '09:55',
#        '08:55', '23:10', '17:30', '18:35', '19:50', '19:25', '00:00',
#        '19:15', '16:55', '11:40', '15:15', '22:55', '22:25', '20:55',
#        '23:05', '09:40', '20:20', '22:35', '23:55', '15:40', '10:30',
#        '10:50', '16:05', '20:15', '12:15', '15:45', '22:15', '10:45',
#        '15:30', '24:05:00', '21:25', '12:45', '21:15', '18:20', '18:25',
#        '11:50', '12:50', '10:55', '21:40', '10:20', '17:55', '23:50',
#        '12:55', '24:10:00', '10:40', '20:45', '23:15', '22:20', '21:05',
#        '0.708333333', '24:15:00', '21:20', '14:35', '10:25', '09:05',
#        '16:50', '08:40', '23:40', '21:50', '19:55', '10:35', '09:25',
# ...

# %%
data['Time_Order_picked']=data['Time_Order_picked'].replace('0.708333333','00:00')
data['Time_Order_picked']=data['Time_Order_picked'].replace('24:10:00','00:00')
data['Time_Order_picked']=data['Time_Order_picked'].replace('24:05:00','00:00')

# %%
data['Time_Order_picked']=data['Time_Order_picked'].replace('24:15:00','00:00')

# %%
data['Time_Order_picked'].unique()
# Out:
# array(['22:10', '15:05', '17:40', '09:30', '20:05', '20:35', '15:10',
#        '20:40', '20:50', '21:30', '20:25', '22:45', '08:30', '19:45',
#        '12:30', '18:50', '23:30', '21:35', '23:45', '22:50', '22:40',
#        '23:35', '13:40', '21:45', '19:10', '14:25', '11:10', '09:55',
#        '08:55', '23:10', '17:30', '18:35', '19:50', '19:25', '00:00',
#        '19:15', '16:55', '11:40', '15:15', '22:55', '22:25', '20:55',
#        '23:05', '09:40', '20:20', '22:35', '23:55', '15:40', '10:30',
#        '10:50', '16:05', '20:15', '12:15', '15:45', '22:15', '10:45',
#        '15:30', '21:25', '12:45', '21:15', '18:20', '18:25', '11:50',
#        '12:50', '10:55', '21:40', '10:20', '17:55', '23:50', '12:55',
#        '10:40', '20:45', '23:15', '22:20', '21:05', '21:20', '14:35',
#        '10:25', '09:05', '16:50', '08:40', '23:40', '21:50', '19:55',
#        '10:35', '09:25', '17:20', '19:30', '17:25', '20:10', '17:35',
# ...

# %%
t1=pd.to_datetime(data['Time_Order_picked'])
# Out:
# C:\Users\Suyash\AppData\Local\Temp\ipykernel_11388\3754393855.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   t1=pd.to_datetime(data['Time_Order_picked'])

# %%
t1.tail(20)
# Out:
# 45564   2023-04-21 20:45:00
# 45565   2023-04-21 22:20:00
# 45566   2023-04-21 00:00:00
# 45567   2023-04-21 17:30:00
# 45568   2023-04-21 22:15:00
# 45569   2023-04-21 10:40:00
# 45570   2023-04-21 18:20:00
# 45571   2023-04-21 09:15:00
# 45572   2023-04-21 20:40:00
# 45573   2023-04-21 09:15:00
# 45574   2023-04-21 21:20:00
# 45575   2023-04-21 09:50:00
# 45576   2023-04-21 18:25:00
# 45577   2023-04-21 00:00:00
# 45578   2023-04-21 21:55:00
# 45579   2023-04-21 11:45:00
# 45580   2023-04-21 20:10:00
# 45581   2023-04-21 00:00:00
# 45582   2023-04-21 13:40:00
# 45583   2023-04-21 17:15:00
# Name: Time_Order_picked, dtype: datetime64[ns]

# %%
t2.tail(20)
# Out:
# 45564   2023-04-20 20:40:00
# 45565   2023-04-20 22:15:00
# 45566   2023-04-20 21:45:00
# 45567   2023-04-20 17:25:00
# 45568   2023-04-20 22:10:00
# 45569   2023-04-20 10:25:00
# 45570   2023-04-20 18:10:00
# 45571   2023-04-20 09:10:00
# 45572   2023-04-20 20:25:00
# 45573   2023-04-20 00:00:00
# 45574   2023-04-20 21:10:00
# 45575   2023-04-20 09:35:00
# 45576   2023-04-20 18:10:00
# 45577   2023-04-20 21:55:00
# 45578   2023-04-20 21:45:00
# 45579   2023-04-20 11:35:00
# 45580   2023-04-20 19:55:00
# 45581   2023-04-20 23:50:00
# 45582   2023-04-20 13:35:00
# 45583   2023-04-20 17:10:00
# Name: Time_Orderd, dtype: datetime64[ns]

# %%
time_for=t1-t2

# %%
time2=time_for

# %%
time2.tail(20)
# Out:
# 45564     0 days 00:05:00
# 45565     0 days 00:05:00
# 45566   -1 days +02:15:00
# 45567     0 days 00:05:00
# 45568     0 days 00:05:00
# 45569     0 days 00:15:00
# 45570     0 days 00:10:00
# 45571     0 days 00:05:00
# 45572     0 days 00:15:00
# 45573     0 days 09:15:00
# 45574     0 days 00:10:00
# 45575     0 days 00:15:00
# 45576     0 days 00:15:00
# 45577   -1 days +02:05:00
# 45578     0 days 00:10:00
# 45579     0 days 00:10:00
# 45580     0 days 00:15:00
# 45581   -1 days +00:10:00
# 45582     0 days 00:05:00
# 45583     0 days 00:05:00
# dtype: timedelta64[ns]

# %%
time2.unique()
# Out:
# array(['0 days 00:15:00', '0 days 00:10:00', '0 days 00:05:00',
#        '0 days 11:10:00', '0 days 23:10:00', 'NaT', '-1 days +13:05:00',
#        '0 days 19:15:00', '-1 days +06:05:00', '-1 days +01:15:00',
#        '-1 days +02:05:00', '-1 days +03:05:00', '-1 days +00:10:00',
#        '-1 days +03:10:00', '0 days 21:15:00', '0 days 23:05:00',
#        '-1 days +00:05:00', '-1 days +01:10:00', '-1 days +15:15:00',
#        '-1 days +04:05:00', '-1 days +07:10:00', '0 days 00:00:00',
#        '0 days 09:05:00', '-1 days +06:15:00', '-1 days +09:10:00',
#        '-1 days +06:10:00', '-1 days +00:15:00', '-1 days +05:15:00',
#        '0 days 19:05:00', '0 days 23:15:00', '0 days 15:10:00',
#        '0 days 09:10:00', '0 days 20:05:00', '-1 days +15:10:00',
#        '-1 days +07:05:00', '-1 days +01:05:00', '0 days 16:15:00',
#        '0 days 18:15:00', '0 days 11:15:00', '0 days 21:10:00',
#        '-1 days +05:05:00', '0 days 10:05:00', '0 days 22:10:00',
# ...

# %%
time2=time2.astype(str)

# %%
v=[]
for i in time2:
    print(i[-5:-3])
    v.append(i[-5:-3])
# Out:
# 15
# 10
# 10
# 10
# 15
# 10
# 15
# 10
# 10
# 15
# 05
# 15
# 15
# 15
# 05
# 15
# 05
# 10
# 15
# 10
# 15
# 05
# 10
# 05
# 10
# 10
# 15
# 10
# 10
# 10
# 15
# 10
# 05
#
# 05
# 15
# 05
# 05
# 15
# 10
# 10
# 05
# 10
# 15
# 10
# 15
# 05
# 15
# 15
# 15
# 05
# 10
# 05
# 15
# 05
# 15
# 10
# 05
# 10
# 10
# 05
# 05
# 15
# 05
# 10
#
# 10
# 15
# 15
# 10
# 10
# 15
# 15
# 05
# 05
# 05
# 10
# 15
# 05
# 15
# 05
# 15
# 10
# 05
# 15
# 05
# 15
# 05
# 10
# 05
# 15
# 15
# 05
# 10
# 15
# 15
# 15
# 05
# 10
# 15
# 10
# 15
# 15
# 05
# 05
# 10
# 05
# 15
# 10
# 10
# 15
#
# 05
# 10
# 10
# 15
# 00
# 10
# 10
# 05
# 15
# 10
# 15
# 05
# 05
# 15
# 05
# 15
# 10
# 15
# 15
#
# 10
# 10
# 05
# 15
# 10
# 10
# 10
# 10
# 05
# 10
# 10
# 10
# 15
# 15
# 10
# 15
# 05
# 05
# 05
# 15
# 05
# 15
# 10
# 10
# 10
# 15
# 05
# 10
# 15
# 05
# 05
# 15
# 05
# 15
# 10
# 05
# 05
# 10
#
# 10
# 15
# 05
# 10
# 10
# 10
# 15
# 05
# 10
# 15
# 10
# 05
# 10
# 10
# 05
# 05
# 15
# 10
# 05
# 15
# 15
# 05
# 15
# 10
# 15
# 15
# 10
# 15
# 15
# 10
# 10
# 05
# ...

# %%
t=pd.Series(v)

# %%
t.tail()
# Out:
# 45579    10
# 45580    15
# 45581    10
# 45582    05
# 45583    05
# dtype: object

# %%
t.shape
# Out:
# (45584,)

# %%
t=t.dropna()

# %%
t=t.replace('','0')

# %%
t=t.astype(float)

# %%
t.shape
# Out:
# (45584,)

# %%
data.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2  \
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude
# 0            30.327968             78.046106                   30.397968  \
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked
# ...

# %%
data['time']=t

# %%
data['time'].nunique()
# Out:
# 4

# %%
data.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2  \
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude
# 0            30.327968             78.046106                   30.397968  \
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd  ...
# ...

# %%
R = 6371
def deg_to_rad(degrees):
    return degrees * (np.pi/180)

# Function to calculate the distance between two points using the haversine formula
def distcalculate(lat1, lon1, lat2, lon2):
    d_lat = deg_to_rad(lat2-lat1)
    d_lon = deg_to_rad(lon2-lon1)
    a = np.sin(d_lat/2)**2 + np.cos(deg_to_rad(lat1)) * np.cos(deg_to_rad(lat2)) * np.sin(d_lon/2)**2
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1-a))
    return R * c
  
# Calculate the distance between each pair of points
data['distance'] = np.nan

for i in range(len(data)):
    data.loc[i, 'distance'] = distcalculate(data.loc[i, 'Restaurant_latitude'], 
                                        data.loc[i, 'Restaurant_longitude'], 
                                        data.loc[i, 'Delivery_location_latitude'], 
                                        data.loc[i, 'Delivery_location_longitude'])

# %%
data.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2  \
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude
# 0            30.327968             78.046106                   30.397968  \
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd  ...
# ...

# %%
data['distance'].dtype
# Out:
# dtype('float64')

# %%
data1=data.copy()

# %%
data1[data1['distance']>30]
# Out:
#            ID Delivery_person_ID  Delivery_person_Age  \
# 83     0xc042     AGRRES010DEL01                 34.0
# 274    0xc044      AGRRES12DEL03                 32.0
# 280     0x4db     PUNERES02DEL03                  NaN
# 416    0xc003      DEHRES13DEL02                  NaN
# 525     0x473      MYSRES07DEL03                  NaN
# ...       ...                ...                  ...
# 44924  0xc0c2     AURGRES03DEL03                 30.0
# 45011   0x56b     PUNERES04DEL01                  NaN
# 45099  0xc01b      GOARES18DEL01                  NaN
# 45173  0xc0c7      KNPRES16DEL02                 30.0
# 45495   0x461     BANGRES07DEL02                  NaN
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# 83                         4.7           -27.163303             78.057044
# 274                        4.7           -27.165108             78.015053
# 280                        NaN           -18.551440            -73.804855
# ...

# %%
index_to_drop = data1[(data1['distance'] == 0) | (data1['distance'] > 25)].index

data1.drop(index_to_drop, inplace = True)

# %%
data1[data1['distance']>30]
# Out:
# Empty DataFrame
# Columns: [ID, Delivery_person_ID, Delivery_person_Age, Delivery_person_Ratings, Restaurant_latitude, Restaurant_longitude, Delivery_location_latitude, Delivery_location_longitude, Order_Date, Time_Orderd, Time_Order_picked, Weather_conditions, Road_traffic_density, Vehicle_condition, Type_of_order, Type_of_vehicle, multiple_deliveries, Festival, City, Time_taken (min), time, distance]
# Index: []
#
# [0 rows x 22 columns]

# %%
df1=data1.drop(labels=['ID','Delivery_person_ID','Restaurant_latitude','Restaurant_longitude','Delivery_location_latitude','Delivery_location_longitude','Order_Date','Time_Orderd','Time_Order_picked','Type_of_order'],axis=1)

# %%
X = df1.drop(labels=['Time_taken (min)'],axis=1)
Y = df1[['Time_taken (min)']]

# %%
num_cols=['Delivery_person_Age','Delivery_person_Ratings','Vehicle_condition','multiple_deliveries','distance','time']

# %%
cat_cols=['Road_traffic_density','Type_of_vehicle','Festival','Weather_conditions','City']

# %%
from sklearn.impute import SimpleImputer ## HAndling Missing Values
from sklearn.preprocessing import StandardScaler # HAndling Feature Scaling
from sklearn.preprocessing import OrdinalEncoder,OneHotEncoder # Ordinal Encoding
## pipelines
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# %%
num_pipeline=Pipeline(
    steps=[
    ('imputer',SimpleImputer(strategy='median')),
    ('scaler',StandardScaler())

    ]

)

# Categorigal Pipeline
cat_pipeline=Pipeline(
    steps=[
    ('imputer',SimpleImputer(strategy='most_frequent')),
    ('ordinalencoder',OneHotEncoder(sparse=False)),
    ('scaler',StandardScaler())
    ]

)

preprocessor=ColumnTransformer([
('num_pipeline',num_pipeline,num_cols),
('cat_pipeline',cat_pipeline,cat_cols)
])

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.30,random_state=30)

# %%
X_train=pd.DataFrame(preprocessor.fit_transform(X_train),columns=preprocessor.get_feature_names_out())
X_test=pd.DataFrame(preprocessor.transform(X_test),columns=preprocessor.get_feature_names_out())
# Out:
# g:\Project\ZomatoTimePredictor\venv\lib\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
regression=LinearRegression()
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
def evaluate_model(true, predicted):
    mae = mean_absolute_error(true, predicted)
    mse = mean_squared_error(true, predicted)
    rmse = np.sqrt(mean_squared_error(true, predicted))
    r2_square = r2_score(true, predicted)
    return mae, rmse, r2_square

# %%
models={
    'LinearRegression':LinearRegression(),
    'Lasso':Lasso(),
    'Ridge':Ridge(),
    'Elasticnet':ElasticNet()
}
trained_model_list=[]
model_list=[]
r2_list=[]

for i in range(len(list(models))):
    model=list(models.values())[i]
    model.fit(X_train,y_train)

    #Make Predictions
    y_pred=model.predict(X_test)

    mae, rmse, r2_square=evaluate_model(y_test,y_pred)

    print(list(models.keys())[i])
    model_list.append(list(models.keys())[i])

    print('Model Training Performance')
    print("RMSE:",rmse)
    print("MAE:",mae)
    print("R2 score",r2_square*100)

    r2_list.append(r2_square)
    
    print('='*35)
    print('\n')
# Out:
# LinearRegression
# Model Training Performance
# RMSE: 6.051025335779455
# MAE: 4.810949276939236
# R2 score 58.82874658403422
# ...
#
#
# Lasso
# Model Training Performance
# RMSE: 6.75827018473321
# MAE: 5.3790512287378345
# R2 score 48.64210127775613
# ...
#
#
# Ridge
# Model Training Performance
# RMSE: 6.048738386964428
# MAE: 4.808743051319004
# R2 score 58.859861560765204
# ...
#
#
# Elasticnet
# Model Training Performance
# RMSE: 6.6747362419857446
# MAE: 5.34304298746079
# R2 score 49.903848475888694
# ...

# %% [markdown]
# ## New

# %%
data.isnull().sum()
# Out:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age            1854
# Delivery_person_Ratings        1908
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1731
# Time_Order_picked                 0
# Weather_conditions              616
# Road_traffic_density            601
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             993
# Festival                        228
# City                           1200
# Time_taken (min)                  0
# time                              0
# distance                          0
# dtype: int64

# %%
data['time'].dtype
# Out:
# dtype('float64')

# %%
df=data.drop(labels=['ID','Delivery_person_ID','Restaurant_latitude','Restaurant_longitude','Delivery_location_latitude','Delivery_location_longitude','Order_Date','Time_Orderd','Time_Order_picked','Type_of_order'],axis=1)

# %%
df.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings Weather_conditions  \
# 0                 36.0                      4.2                Fog
# 1                 21.0                      4.7             Stormy
# 2                 23.0                      4.7         Sandstorms
# 3                 34.0                      4.3         Sandstorms
# 4                 24.0                      4.7                Fog
#
#   Road_traffic_density  Vehicle_condition Type_of_vehicle  \
# 0                  Jam                  2      motorcycle
# 1                 High                  1      motorcycle
# 2               Medium                  1         scooter
# 3                  Low                  0      motorcycle
# 4                  Jam                  1         scooter
#
#    multiple_deliveries Festival           City  Time_taken (min)  time  \
# 0                  3.0       No  Metropolitian                46  15.0
# ...

# %%
df.shape
# Out:
# (45584, 12)

# %%
## Independent and dependent features
X = df.drop(labels=['Time_taken (min)'],axis=1)
Y = df[['Time_taken (min)']]

# %%
X.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings Weather_conditions  \
# 0                 36.0                      4.2                Fog
# 1                 21.0                      4.7             Stormy
# 2                 23.0                      4.7         Sandstorms
# 3                 34.0                      4.3         Sandstorms
# 4                 24.0                      4.7                Fog
#
#   Road_traffic_density  Vehicle_condition Type_of_vehicle  \
# 0                  Jam                  2      motorcycle
# 1                 High                  1      motorcycle
# 2               Medium                  1         scooter
# 3                  Low                  0      motorcycle
# 4                  Jam                  1         scooter
#
#    multiple_deliveries Festival           City  time   distance
# 0                  3.0       No  Metropolitian  15.0  10.280582
# 1                  1.0       No  Metropolitian  10.0   6.242319
# ...

# %%
num_cols=['Delivery_person_Age','Delivery_person_Ratings','Vehicle_condition','multiple_deliveries','distance','time']

# %%
cat_cols=['Road_traffic_density','Type_of_vehicle','Festival','Weather_conditions','City']

# %%
from sklearn.impute import SimpleImputer ## HAndling Missing Values
from sklearn.preprocessing import StandardScaler # HAndling Feature Scaling
from sklearn.preprocessing import OrdinalEncoder,OneHotEncoder # Ordinal Encoding
## pipelines
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# %%
## Numerical Pipeline
num_pipeline=Pipeline(
    steps=[
    ('imputer',SimpleImputer(strategy='median')),
    ('scaler',StandardScaler())

    ]

)

# Categorigal Pipeline
cat_pipeline=Pipeline(
    steps=[
    ('imputer',SimpleImputer(strategy='most_frequent')),
    ('ordinalencoder',OneHotEncoder(sparse=False)),
    ('scaler',StandardScaler())
    ]

)

preprocessor=ColumnTransformer([
('num_pipeline',num_pipeline,num_cols),
('cat_pipeline',cat_pipeline,cat_cols)
])

# %%
## Train test split

from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.30,random_state=30)

# %%
X_train=pd.DataFrame(preprocessor.fit_transform(X_train),columns=preprocessor.get_feature_names_out())
X_test=pd.DataFrame(preprocessor.transform(X_test),columns=preprocessor.get_feature_names_out())

# %%
X_train.head()
# Out:
#    num_pipeline__Delivery_person_Age  num_pipeline__Delivery_person_Ratings  \
# 0                           1.124025                              -1.623440
# 1                          -0.106505                              -3.143059
# 2                           0.245075                               0.504025
# 3                           0.596655                              -1.319517
# 4                           0.772445                              -1.623440
#
#    num_pipeline__Vehicle_condition  num_pipeline__multiple_deliveries  \
# 0                        -1.223528                          -1.318236
# 1                        -1.223528                           3.943714
# 2                         1.160323                           0.435747
# 3                         1.160323                           0.435747
# 4                        -1.223528                           0.435747
#
#    num_pipeline__distance  num_pipeline__time  \
# ...

# %%
X_train.isnull().sum()
# Out:
# num_pipeline__Delivery_person_Age                 0
# num_pipeline__Delivery_person_Ratings             0
# num_pipeline__Vehicle_condition                   0
# num_pipeline__multiple_deliveries                 0
# num_pipeline__distance                            0
# num_pipeline__time                                0
# cat_pipeline__Road_traffic_density_High           0
# cat_pipeline__Road_traffic_density_Jam            0
# cat_pipeline__Road_traffic_density_Low            0
# cat_pipeline__Road_traffic_density_Medium         0
# cat_pipeline__Type_of_vehicle_bicycle             0
# cat_pipeline__Type_of_vehicle_electric_scooter    0
# cat_pipeline__Type_of_vehicle_motorcycle          0
# cat_pipeline__Type_of_vehicle_scooter             0
# cat_pipeline__Festival_No                         0
# cat_pipeline__Festival_Yes                        0
# cat_pipeline__Weather_conditions_Cloudy           0
# cat_pipeline__Weather_conditions_Fog              0
# ...

# %%
## Model Training

from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
regression=LinearRegression()
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
regression.coef_
# Out:
# array([[ 2.26485179e+00, -2.40006108e+00, -1.73389226e+00,
#          1.83464724e+00,  1.54373958e-01, -1.45924609e-01,
#          8.47012468e+12,  1.32896947e+13,  1.37138786e+13,
#          1.22535268e+13, -2.96341020e+11, -2.21579390e+12,
#         -3.94262245e+12, -3.77057236e+12,  7.40979832e+13,
#          7.40979832e+13,  2.81848929e+12,  2.91864705e+12,
#          2.79744744e+12,  2.81144285e+12,  2.77956903e+12,
#          2.80327971e+12,  1.57229550e+12,  2.22918431e+11,
#          1.56347187e+12]])

# %%
regression.intercept_
# Out:
# array([26.32069542])

# %%
def evaluate_model(true, predicted):
    mae = mean_absolute_error(true, predicted)
    mse = mean_squared_error(true, predicted)
    rmse = np.sqrt(mean_squared_error(true, predicted))
    r2_square = r2_score(true, predicted)
    return mae, rmse, r2_square

# %%
## Train multiple models

models={
    'LinearRegression':LinearRegression(),
    'Lasso':Lasso(),
    'Ridge':Ridge(),
    'Elasticnet':ElasticNet()
}
trained_model_list=[]
model_list=[]
r2_list=[]

for i in range(len(list(models))):
    model=list(models.values())[i]
    model.fit(X_train,y_train)

    #Make Predictions
    y_pred=model.predict(X_test)

    mae, rmse, r2_square=evaluate_model(y_test,y_pred)

    print(list(models.keys())[i])
    model_list.append(list(models.keys())[i])

    print('Model Training Performance')
    print("RMSE:",rmse)
    print("MAE:",mae)
    print("R2 score",r2_square*100)

    r2_list.append(r2_square)
    
    print('='*35)
    print('\n')
# Out:
# LinearRegression
# Model Training Performance
# RMSE: 6.2862657649181495
# MAE: 4.969511808354413
# R2 score 54.31276297207851
# ...
#
#
# Lasso
# Model Training Performance
# RMSE: 6.88622666394678
# MAE: 5.444419880970748
# R2 score 45.1758324215739
# ...
#
#
# Ridge
# Model Training Performance
# RMSE: 6.285381008442772
# MAE: 4.968282175775417
# R2 score 54.325622509274105
# ...
#
#
# Elasticnet
# Model Training Performance
# RMSE: 6.806748862228143
# MAE: 5.420308878434111
# R2 score 46.43404231964059
# ...

# %%
model_list
# Out:
# ['LinearRegression', 'Lasso', 'Ridge', 'Elasticnet']

# %%
R = 6371
def deg_to_rad(degrees):
    return degrees * (np.pi/180)

# Function to calculate the distance between two points using the haversine formula
def distcalculate(lat1, lon1, lat2, lon2):
    d_lat = deg_to_rad(lat2-lat1)
    d_lon = deg_to_rad(lon2-lon1)
    a = np.sin(d_lat/2)**2 + np.cos(deg_to_rad(lat1)) * np.cos(deg_to_rad(lat2)) * np.sin(d_lon/2)**2
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1-a))
    return R * c
  
# Calculate the distance between each pair of points
data['distance'] = np.nan

for i in range(len(data)):
    data.loc[i, 'distance'] = distcalculate(data.loc[i, 'Restaurant_latitude'], 
                                        data.loc[i, 'Restaurant_longitude'], 
                                        data.loc[i, 'Delivery_location_latitude'], 
                                        data.loc[i, 'Delivery_location_longitude'])

# %%
data.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            30.327968             78.046106                   30.397968
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd  ...  \
# ...

# %%
data=data.drop(labels=['ID','Delivery_person_ID','Restaurant_latitude','Restaurant_longitude','Delivery_location_latitude','Delivery_location_longitude'],axis=1)

# %%
data=data.drop(labels=['Order_Date','Time_Orderd','Time_Order_picked','Type_of_order'],axis=1)

# %%
data.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings Weather_conditions  \
# 0                 36.0                      4.2                Fog
# 1                 21.0                      4.7             Stormy
# 2                 23.0                      4.7         Sandstorms
# 3                 34.0                      4.3         Sandstorms
# 4                 24.0                      4.7                Fog
#
#   Road_traffic_density  Vehicle_condition Type_of_vehicle  \
# 0                  Jam                  2      motorcycle
# 1                 High                  1      motorcycle
# 2               Medium                  1         scooter
# 3                  Low                  0      motorcycle
# 4                  Jam                  1         scooter
#
#    multiple_deliveries Festival           City  Time_taken (min)   distance
# 0                  3.0       No  Metropolitian                46  10.280582
# ...

# %%
data.shape
# Out:
# (45584, 11)

# %%
X=data.drop(labels=['Time_taken (min)'],axis=1)
y=data[['Time_taken (min)']]

# %%
X.shape
# Out:
# (45584, 10)

# %%
X.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings Weather_conditions  \
# 0                 36.0                      4.2                Fog
# 1                 21.0                      4.7             Stormy
# 2                 23.0                      4.7         Sandstorms
# 3                 34.0                      4.3         Sandstorms
# 4                 24.0                      4.7                Fog
#
#   Road_traffic_density  Vehicle_condition Type_of_vehicle  \
# 0                  Jam                  2      motorcycle
# 1                 High                  1      motorcycle
# 2               Medium                  1         scooter
# 3                  Low                  0      motorcycle
# 4                  Jam                  1         scooter
#
#    multiple_deliveries Festival           City   distance
# 0                  3.0       No  Metropolitian  10.280582
# 1                  1.0       No  Metropolitian   6.242319
# ...

# %%
y
# Out:
#        Time_taken (min)
# 0                    46
# 1                    23
# 2                    21
# 3                    20
# 4                    41
# ...                 ...
# 45579                32
# 45580                36
# 45581                16
# 45582                26
# 45583                36
#
# [45584 rows x 1 columns]

# %%
# Define which columns should be encoded and which should be scaled
num_cols=['Delivery_person_Age','Delivery_person_Ratings','Vehicle_condition','multiple_deliveries','distance']
cat_cols=['Road_traffic_density','Type_of_vehicle','Festival','Weather_conditions','City']

# %%
# Define the custom ranking for each ordinal variable
cat_Traffic_density=['Low','Jam','Medium','High'] 
cat_type_of_vehical=['motorcycle','scooter','electric_scooter','bicycle'] # onehot encoder
cat_festival=['No','Yes']#onehot
cat_weather=['Fog','Stormy','Cloudy','Sandstorms','Windy','Sunny']#onehot
cat_city=['Metropolitian','Urban','Semi-Urban']#onehot

# %%
from sklearn.impute import SimpleImputer ## HAndling Missing Values
from sklearn.preprocessing import StandardScaler # HAndling Feature Scaling
from sklearn.preprocessing import OrdinalEncoder,OneHotEncoder # Ordinal Encoding
## pipelines
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# %%
## Numerical Pipeline
num_pipeline=Pipeline(
    steps=[
    ('imputer',SimpleImputer(strategy='median')),
    ('scaler',StandardScaler())

    ]

)

# Categorigal Pipeline
cat_pipeline=Pipeline(
    steps=[
    ('imputer',SimpleImputer(strategy='most_frequent')),
    ("OneHotEncoder", OneHotEncoder(sparse=False)),
    ('scaler',StandardScaler())
    ]

)

preprocessor=ColumnTransformer([
('num_pipeline',num_pipeline,num_cols),
('cat_pipeline',cat_pipeline,cat_cols)
])

# %%
## Train test split

from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.30,random_state=30)

# %%
X_train=pd.DataFrame(preprocessor.fit_transform(X_train),columns=preprocessor.get_feature_names_out())
X_test=pd.DataFrame(preprocessor.transform(X_test),columns=preprocessor.get_feature_names_out())

# %%
X_train.head()
# Out:
#    num_pipeline__Delivery_person_Age  num_pipeline__Delivery_person_Ratings  \
# 0                           1.124025                              -1.623440
# 1                          -0.106505                              -3.143059
# 2                           0.245075                               0.504025
# 3                           0.596655                              -1.319517
# 4                           0.772445                              -1.623440
#
#    num_pipeline__Vehicle_condition  num_pipeline__multiple_deliveries  \
# 0                        -1.223528                          -1.318236
# 1                        -1.223528                           3.943714
# 2                         1.160323                           0.435747
# 3                         1.160323                           0.435747
# 4                        -1.223528                           0.435747
#
#    num_pipeline__distance  cat_pipeline__Road_traffic_density_High  \
# ...

# %%
## Model Training

from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
regression=LinearRegression()
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
regression.coef_
# Out:
# array([[ 2.26775119e+00, -2.39848723e+00, -1.72755839e+00,
#          1.84423144e+00,  1.76552869e-01,  1.20301937e+13,
#          1.88754721e+13,  1.94779443e+13,  1.74037935e+13,
#         -4.33267888e+11, -3.23962017e+12, -5.76434441e+12,
#         -5.51279712e+12,  2.26961849e+13,  2.26961849e+13,
#         -1.22743845e+13, -1.27105666e+13, -1.21827482e+13,
#         -1.22436975e+13, -1.21048886e+13, -1.22081474e+13,
#          3.74531068e+13,  5.31006278e+12,  3.72429223e+13]])

# %%
regression.intercept_
# Out:
# array([26.31776823])

# %%
def evaluate_model(true, predicted):
    mae = mean_absolute_error(true, predicted)
    mse = mean_squared_error(true, predicted)
    rmse = np.sqrt(mean_squared_error(true, predicted))
    r2_square = r2_score(true, predicted)
    return mae, rmse, r2_square

# %%
## Train multiple models

models={
    'LinearRegression':LinearRegression(),
    'Lasso':Lasso(),
    'Ridge':Ridge(),
    'Elasticnet':ElasticNet()
}
trained_model_list=[]
model_list=[]
r2_list=[]

for i in range(len(list(models))):
    model=list(models.values())[i]
    model.fit(X_train,y_train)

    #Make Predictions
    y_pred=model.predict(X_test)

    mae, rmse, r2_square=evaluate_model(y_test,y_pred)

    print(list(models.keys())[i])
    model_list.append(list(models.keys())[i])

    print('Model Training Performance')
    print("RMSE:",rmse)
    print("MAE:",mae)
    print("R2 score",r2_square*100)

    r2_list.append(r2_square)
    
    print('='*35)
    print('\n')
# Out:
# LinearRegression
# Model Training Performance
# RMSE: 6.288046339569239
# MAE: 4.9716865447783025
# R2 score 54.286877634030326
# ...
#
#
# Lasso
# Model Training Performance
# RMSE: 6.88622666394678
# MAE: 5.444419880970748
# R2 score 45.1758324215739
# ...
#
#
# Ridge
# Model Training Performance
# RMSE: 6.28667494532876
# MAE: 4.970033019543478
# R2 score 54.30681510683593
# ...
#
#
# Elasticnet
# Model Training Performance
# RMSE: 6.806748862228143
# MAE: 5.420308878434112
# R2 score 46.43404231964059
# ...
